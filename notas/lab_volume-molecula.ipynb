  14  -0.65617367710429   0.80981909559222   5.18064043382431  1.89169
  15  -0.59784979866343  -1.31627449866029   6.88691167722901  1.89169
  16   0.03303074949103  -3.64710941833820   6.08375278111789  1.89169
  17   1.37627094274358  -8.11314484475442   3.91002991542463  1.41902
  18   2.40159488527471  -5.25143219433266  -3.58956420582359  1.41902
  19   2.46015021140317  -8.79291821588666  -0.56703863062252  1.41902
  20   1.69118853069857  -0.67734634562460  -4.50755303461973  1.41902
  21  -0.76399451630967   6.43933733858452   0.43867408020473  1.41902
  22  -1.84729302220579   7.11920463188852   4.91585513034577  1.41902
  23  -1.78784551759934   3.57789441905782   7.93856153621960  1.41902
  24  -1.07869254901855  -0.99644803266090   8.85628771758807  1.41902
  25   0.06468337227898  -5.22090135029369   7.40060911391063  1.41902
  26   0.54710073020911   3.54696451765081  -3.05205287652764  1.41902""".split("\n")], columns=["id", "x", "y", "z", "r"])

# %%
df
# Out:
#     id         x         y         z        r
# 0    1  1.342739 -6.535512  2.598854  1.89169
# 1    2  1.951646 -6.913885  0.080429  1.89169
# 2    3  0.680495 -4.128284  3.479091  1.89169
# 3    4  0.641003 -2.071816  1.748909  1.89169
# 4    5  1.269511 -2.483433 -0.831730  1.89169
# 5    6  1.919749 -4.924832 -1.622233  1.89169
# 6    7  1.210726 -0.357432 -2.538099  1.89169
# 7    8  0.579478  1.973332 -1.735021  1.89169
# 8    9 -0.067577  2.454593  0.869733  1.89169
# 9   10 -0.027686  0.398196  2.599995  1.89169
# 10  11 -0.729998  4.861785  1.749932  1.89169
# 11  12 -1.338596  5.240209  4.268423  1.89169
# 12  13 -1.306271  3.251243  5.971176  1.89169
# 13  14 -0.656174  0.809819  5.180640  1.89169
# 14  15 -0.597850 -1.316274  6.886912  1.89169
# 15  16  0.033031 -3.647109  6.083753  1.89169
# 16  17  1.376271 -8.113145  3.910030  1.41902
# 17  18  2.401595 -5.251432 -3.589564  1.41902
# 18  19  2.460150 -8.792918 -0.567039  1.41902
# ...

# %% [markdown]
# transforma tipos de variáveis

# %%
df[["x", "y", "z", "r"]] = df[["x", "y", "z", "r"]].astype(np.float64)

# %%
df['id'] = df['id'].astype(np.int64).astype(str)

# %%
desc = df.describe().copy()
desc
# Out:
#                x          y          z          r
# count  26.000000  26.000000  26.000000  26.000000
# mean    0.306438  -0.836854   2.174407   1.709894
# std     1.283783   4.598180   3.827339   0.234510
# min    -1.847293  -8.792918  -4.507553   1.419020
# 25%    -0.711542  -4.725695  -0.765557   1.419020
# 50%     0.305892  -0.836897   2.174393   1.891690
# 75%     1.324432   3.052080   5.114444   1.891690
# max     2.460150   7.119205   8.856288   1.891690

# %% [markdown]
# maximiza tamanho da aresta do cubo

# %%
max_ = np.ceil(np.max(np.abs( desc.loc[['min', 'max'], ['x', 'y', 'z']].values )) + desc.loc[['min', 'max'], ['r']].max()[0])
max_
# Out:
# 11.0

# %%
dict_ = df.set_index('id').to_dict("index")
dict_
# Out:
# {'1': {'x': 1.34273871328488,
#   'y': -6.53551214947057,
#   'z': 2.59885384188836,
#   'r': 1.89169},
#  '2': {'x': 1.95164562808441,
#   'y': -6.91388520966513,
#   'z': 0.08042942907465,
#   'r': 1.89169},
#  '3': {'x': 0.68049483353634,
#   'y': -4.12828431867417,
#   'z': 3.47909099832029,
#   'r': 1.89169},
#  '4': {'x': 0.64100333782321,
#   'y': -2.07181577792282,
#   'z': 1.74890919954582,
#   'r': 1.89169},
#  '5': {'x': 1.26951073292859,
#   'y': -2.48343291222426,
#   'z': -0.83172971287278,
#   'r': 1.89169},
#  '6': {'x': 1.91974901037739,
#   'y': -4.92483242868132,
#   'z': -1.6222325690523,
#   'r': 1.89169},
#  '7': {'x': 1.21072560517071,
#   'y': -0.35743156210634,
#   'z': -2.53809909991914,
#   'r': 1.89169},
#  '8': {'x': 0.57947819147196,
#   'y': 1.97333184988525,
#   'z': -1.73502093710113,
#   'r': 1.89169},
#  '9': {'x': -0.06757707646816,
#   'y': 2.45459311022218,
#   'z': 0.86973258468797,
#   'r': 1.89169},
#  '10': {'x': -0.02768614332002,
# ...

# %%
# %%time


MEAN   = list() # valores das tentativas
NTRIAL = 23

for j in range(NTRIAL):
    N  = 77      # numero de pontos
    V  = list()  # estimativa de volume em funcao de N
    T_ = 0       # contagem de pontos dentro

    # para cada ponto
    for i in range(N):
        x_ = np.random.uniform(-max_, max_)
        y_ = np.random.uniform(-max_, max_)
        z_ = np.random.uniform(-max_, max_)
        DENTRO = False
        
        # para cada atomo
        for k in dict_:
            # verifica se esta dentro do raio da cavidade
            if np.sqrt( (dict_[k]['x'] - x_)**2 + (dict_[k]['y'] - y_)**2 + (dict_[k]['z'] - z_)**2 ) <= dict_[k]['r']:
                DENTRO = True
                continue
        if DENTRO: 
            T_ += 1
            V.append( (T_/(i+1)) * (2*max_)**3 )
        else: 
            V.append( (T_/(i+1)) * (2*max_)**3 )
    
    print(rf"TRIAL {j}: ", V[-1])
    MEAN.append(V[-1])

print()
print(rf"{np.mean(MEAN)} ({np.std(MEAN)})")
# Out:
# TRIAL 0:  829.7142857142857
# TRIAL 1:  414.85714285714283
# TRIAL 2:  414.85714285714283
# TRIAL 3:  968.0
# TRIAL 4:  553.1428571428572
# TRIAL 5:  553.1428571428572
# TRIAL 6:  691.4285714285713
# TRIAL 7:  553.1428571428572
# TRIAL 8:  138.2857142857143
# TRIAL 9:  414.85714285714283
# TRIAL 10:  553.1428571428572
# TRIAL 11:  138.2857142857143
# TRIAL 12:  691.4285714285713
# TRIAL 13:  691.4285714285713
# TRIAL 14:  829.7142857142857
# TRIAL 15:  553.1428571428572
# TRIAL 16:  414.85714285714283
# TRIAL 17:  553.1428571428572
# TRIAL 18:  553.1428571428572
# TRIAL 19:  276.5714285714286
# TRIAL 20:  276.5714285714286
# TRIAL 21:  553.1428571428572
# TRIAL 22:  276.5714285714286
#
# 517.0683229813665 (208.79646189877522)
# CPU times: user 85.1 ms, sys: 17 µs, total: 85.1 ms
# Wall time: 83.8 ms

# %%
# %%time

MEAN = list()

for j in range(23):
    N  = 777
    V  = list()
    T_ = 0

    for i in range(N):
        x_ = np.random.uniform(-max_, max_)
        y_ = np.random.uniform(-max_, max_)
        z_ = np.random.uniform(-max_, max_)
        DENTRO = False

        for k in dict_:
            if np.sqrt( (dict_[k]['x'] - x_)**2 + (dict_[k]['y'] - y_)**2 + (dict_[k]['z'] - z_)**2 ) <= dict_[k]['r']:
                DENTRO = True
                continue

        if DENTRO: 
            T_ += 1
            V.append( (T_/(i+1)) * (2*max_)**3 )
        else: 
            V.append( (T_/(i+1)) * (2*max_)**3 )
    
    print(rf"TRIAL {j}: ", V[-1])
    MEAN.append(V[-1])

print()
print(rf"{np.mean(MEAN)} ({np.std(MEAN)})")
# Out:
# TRIAL 0:  616.6795366795367
# TRIAL 1:  438.5276705276705
# TRIAL 2:  424.82368082368083
# TRIAL 3:  589.2715572715573
# TRIAL 4:  479.6396396396396
# TRIAL 5:  452.2316602316602
# TRIAL 6:  397.4157014157014
# TRIAL 7:  465.9356499356499
# TRIAL 8:  548.1595881595881
# TRIAL 9:  616.6795366795367
# TRIAL 10:  507.04761904761904
# TRIAL 11:  507.04761904761904
# TRIAL 12:  479.6396396396396
# TRIAL 13:  424.82368082368083
# TRIAL 14:  383.7117117117117
# TRIAL 15:  589.2715572715573
# TRIAL 16:  575.5675675675676
# TRIAL 17:  479.6396396396396
# TRIAL 18:  479.6396396396396
# TRIAL 19:  465.9356499356499
# TRIAL 20:  465.9356499356499
# TRIAL 21:  370.007722007722
# TRIAL 22:  520.7516087516087
#
# 490.36450114710976 (70.1051596981572)
# CPU times: user 757 ms, sys: 3.94 ms, total: 761 ms
# Wall time: 758 ms

# %%
# %%time

MEAN = list()

for j in range(23):
    N  = 7777
    V  = list()
    T_ = 0

    for i in range(N):
        x_ = np.random.uniform(-max_, max_)
        y_ = np.random.uniform(-max_, max_)
        z_ = np.random.uniform(-max_, max_)
        DENTRO = False

        for k in dict_:
            if np.sqrt( (dict_[k]['x'] - x_)**2 + (dict_[k]['y'] - y_)**2 + (dict_[k]['z'] - z_)**2 ) <= dict_[k]['r']:
                DENTRO = True
                continue

        if DENTRO: 
            T_ += 1
            V.append( (T_/(i+1)) * (2*max_)**3 )
        else: 
            V.append( (T_/(i+1)) * (2*max_)**3 )
    
    print(rf"TRIAL {j}: ", V[-1])
    MEAN.append(V[-1])

print()
print(rf"{np.mean(MEAN)} ({np.std(MEAN)})")
# Out:
# TRIAL 0:  484.68458274398864
# TRIAL 1:  498.3762376237624
# TRIAL 2:  484.68458274398864
# TRIAL 3:  486.05374823196604
# TRIAL 4:  472.36209335219235
# TRIAL 5:  439.50212164073554
# TRIAL 6:  466.8854314002829
# TRIAL 7:  418.96463932107497
# TRIAL 8:  449.0862800565771
# TRIAL 9:  428.5487977369166
# TRIAL 10:  451.82461103253183
# TRIAL 11:  435.3946251768034
# TRIAL 12:  498.3762376237624
# TRIAL 13:  497.00707213578505
# TRIAL 14:  479.2079207920792
# TRIAL 15:  464.14710042432813
# TRIAL 16:  429.9179632248939
# TRIAL 17:  517.5445544554456
# TRIAL 18:  450.45544554455444
# TRIAL 19:  468.25459688826027
# TRIAL 20:  440.8712871287129
# TRIAL 21:  502.4837340876945
# TRIAL 22:  424.44130127298445
#
# 464.74238976692703 (27.957185823001687)
# CPU times: user 7.23 s, sys: 7.23 ms, total: 7.24 s
# Wall time: 7.24 s

# %%
# %%time

MEAN = list()

for j in range(23):
    N  = 77777
    V  = list()
    T_ = 0

    for i in range(N):
        x_ = np.random.uniform(-max_, max_)
        y_ = np.random.uniform(-max_, max_)
        z_ = np.random.uniform(-max_, max_)
        DENTRO = False

        for k in dict_:
            if np.sqrt( (dict_[k]['x'] - x_)**2 + (dict_[k]['y'] - y_)**2 + (dict_[k]['z'] - z_)**2 ) <= dict_[k]['r']:
                DENTRO = True
                continue

        if DENTRO: 
            T_ += 1
            V.append( (T_/(i+1)) * (2*max_)**3 )
        else: 
            V.append( (T_/(i+1)) * (2*max_)**3 )
    
    print(rf"TRIAL {j}: ", V[-1])
    MEAN.append(V[-1])

print()
print(rf"{np.mean(MEAN)} ({np.std(MEAN)})")
# Out:
# TRIAL 0:  467.80174087455157
# TRIAL 1:  476.15289867184384
# TRIAL 2:  465.47436902940456
# TRIAL 3:  483.13501420728494
# TRIAL 4:  491.4861720045772
# TRIAL 5:  468.89697468403256
# TRIAL 6:  492.58140581405814
# TRIAL 7:  476.8374198027695
# TRIAL 8:  468.21245355310697
# TRIAL 9:  485.05167337387655
# TRIAL 10:  479.9862170050272
# TRIAL 11:  464.6529436722939
# TRIAL 12:  469.44459158877305
# TRIAL 13:  468.89697468403256
# TRIAL 14:  474.5100479576225
# TRIAL 15:  462.1886676009617
# TRIAL 16:  472.867197243401
# TRIAL 17:  482.03978039780395
# TRIAL 18:  477.24813248132483
# TRIAL 19:  481.76597194543376
# TRIAL 20:  475.05766486236286
# TRIAL 21:  463.1469971842576
# TRIAL 22:  476.9743240289546
#
# 474.97433185511983 (8.320778609935271)
# CPU times: user 1min 12s, sys: 36.4 ms, total: 1min 12s
# Wall time: 1min 12s

# %%
# %%time

MEAN = list()

for j in range(23):
    N  = 100000
    V  = list()
    T_ = 0

    for i in range(N):
        x_ = np.random.uniform(-max_, max_)
        y_ = np.random.uniform(-max_, max_)
        z_ = np.random.uniform(-max_, max_)
        DENTRO = False

        for k in dict_:
            if np.sqrt( (dict_[k]['x'] - x_)**2 + (dict_[k]['y'] - y_)**2 + (dict_[k]['z'] - z_)**2 ) <= dict_[k]['r']:
                DENTRO = True
                continue

        if DENTRO: 
            T_ += 1
            V.append( (T_/(i+1)) * (2*max_)**3 )
        else: 
            V.append( (T_/(i+1)) * (2*max_)**3 )
    
    print(rf"TRIAL {j}: ", V[-1])
    MEAN.append(V[-1])

print()
print(rf"{np.mean(MEAN)} ({np.std(MEAN)})")
# Out:
# TRIAL 0:  462.01671999999996
# TRIAL 1:  479.6924
# TRIAL 2:  481.28959999999995
# TRIAL 3:  462.97504
# TRIAL 4:  481.28959999999995
# TRIAL 5:  469.89624000000003
# TRIAL 6:  469.89624000000003
# TRIAL 7:  470.85456000000005
# TRIAL 8:  478.84056000000004
# TRIAL 9:  478.52112
# TRIAL 10:  476.71095999999994
# TRIAL 11:  475.22024000000005
# TRIAL 12:  493.64128
# TRIAL 13:  481.18312000000003
# TRIAL 14:  475.00728
# TRIAL 15:  475.53968
# TRIAL 16:  467.12775999999997
# TRIAL 17:  469.89624000000003
# TRIAL 18:  473.3036
# TRIAL 19:  475.32671999999997
# TRIAL 20:  470.53512
# TRIAL 21:  474.79431999999997
# TRIAL 22:  475.75264
#
# 474.75265391304345 (6.626261617214613)
# CPU times: user 1min 33s, sys: 26.6 ms, total: 1min 33s
# Wall time: 1min 33s

# %%
# %%time

MEAN = list()

for j in range(23):
    N  = 500000
    V  = list()
    T_ = 0

    for i in range(N):
        x_ = np.random.uniform(-max_, max_)
        y_ = np.random.uniform(-max_, max_)
        z_ = np.random.uniform(-max_, max_)
        DENTRO = False

        for k in dict_:
            if np.sqrt( (dict_[k]['x'] - x_)**2 + (dict_[k]['y'] - y_)**2 + (dict_[k]['z'] - z_)**2 ) <= dict_[k]['r']:
                DENTRO = True
                continue

        if DENTRO: 
            T_ += 1
            V.append( (T_/(i+1)) * (2*max_)**3 )
        else: 
            V.append( (T_/(i+1)) * (2*max_)**3 )
    
    print(rf"TRIAL {j}: ", V[-1])
    MEAN.append(V[-1])

print()
print(rf"{np.mean(MEAN)} ({np.std(MEAN)})")
# Out:
# TRIAL 0:  473.36748800000004
# TRIAL 1:  472.79249599999997
# TRIAL 2:  472.79249599999997
# TRIAL 3:  475.85912
# TRIAL 4:  476.306336
# TRIAL 5:  474.83691200000004
# TRIAL 6:  476.09337600000003
# TRIAL 7:  481.268304
# TRIAL 8:  471.38696
# TRIAL 9:  471.876768
# TRIAL 10:  475.4332
# TRIAL 11:  477.45632
# TRIAL 12:  473.261008
# TRIAL 13:  473.34619200000003
# TRIAL 14:  475.177648
# TRIAL 15:  473.857296
# TRIAL 16:  477.371136
# TRIAL 17:  475.71004800000003
# TRIAL 18:  476.668368
# TRIAL 19:  478.77667199999996
# TRIAL 20:  471.23788799999994
# TRIAL 21:  476.19985599999995
# TRIAL 22:  477.77576
#
# 475.1674629565217 (2.443465049068165)
# CPU times: user 7min 46s, sys: 395 ms, total: 7min 47s
# Wall time: 7min 47s

# %% [markdown]
# - - -

# %%
# plota apenas o ultimo NTRIAL
plt.plot(range(len(V))[:1000], V[:1000])

# %%
plt.hist(V[:1000], bins=777);

# %% [markdown]
# RESPOSTA = $256\, A^3$

# %% [markdown]
# # formato 2

# %%
df = pd.DataFrame([i.split() for i in """    1 1    0.9650959051E+01    0.6005768802E+01   -0.4094294569E+01
    2 1    0.8315508525E+01    0.5920725212E+01   -0.4493139850E+01
  172 2    0.2192727097E+02    0.1547372237E+02   -0.7376821389E+01
  173 2    0.2193896473E+02    0.1783889206E+02   -0.5444234986E+01
  174 2    0.2265862746E+02    0.1781204189E+02   -0.7043475172E+01
  175 2    0.2331423200E+02    0.1680368481E+02   -0.5766894195E+01
  176 1    0.1518199314E+02    0.1128388361E+02    0.4184334208E+01
  177 1    0.1393574984E+02    0.1211892069E+02    0.3906519537E+01
  178 2    0.1595458970E+02    0.1192875871E+02    0.4605800105E+01
  179 2    0.1494932349E+02    0.1054341710E+02    0.4951122874E+01
  180 1    0.1339864228E+02    0.1281751138E+02    0.5145256621E+01
  181 2    0.1315982369E+02    0.1148036966E+02    0.3481179259E+01
  182 2    0.1416048906E+02    0.1285950051E+02    0.3137282664E+01
  183 1    0.1215578822E+02    0.1364887406E+02    0.4868802522E+01
  184 2    0.1417670346E+02    0.1345472675E+02    0.5569985212E+01
  185 2    0.1317728400E+02    0.1207524184E+02    0.5914589885E+01
  186 1    0.1161638086E+02    0.1434939712E+02    0.6106402309E+01
  187 2    0.1137869744E+02    0.1301084483E+02    0.4444058234E+01
  188 2    0.1237793959E+02    0.1439001358E+02    0.4098937289E+01
  189 1    0.1037834783E+02    0.1517806823E+02    0.5836772647E+01
  190 2    0.1239478165E+02    0.1498706237E+02    0.6529626789E+01
  191 2    0.1139560639E+02    0.1360679404E+02    0.6875473407E+01
  192 2    0.1057450281E+02    0.1595543238E+02    0.5103826431E+01
  193 2    0.1002523743E+02    0.1566082415E+02    0.6743309885E+01
  194 2    0.9568095277E+01    0.1456523324E+02    0.5452160044E+01""".split("\n")], columns=["line", "id", "x", "y", "z"])

# %%
df['id'].unique()
# Out:
# array(['1', '2', '3', '4', '5'], dtype=object)

# %%
cond = [df['id'] == '1',
        df['id'] == '2',
        df['id'] == '3',
        df['id'] == '4',
        df['id'] == '5',]

choice = [1.0, 1.1, 1.2, 1.3, 1.4]

df['r'] = np.select(cond, choice)

# %%
df
# Out:
#     line id                 x                 y                  z    r
# 0      1  1  0.9650959051E+01  0.6005768802E+01  -0.4094294569E+01  1.0
# 1      2  1  0.8315508525E+01  0.5920725212E+01  -0.4493139850E+01  1.0
# 2      3  1  0.7705306415E+01  0.4676272980E+01  -0.4551152179E+01  1.0
# 3      4  1  0.8397563215E+01  0.3517879096E+01  -0.4220037981E+01  1.0
# 4      5  1  0.9720917570E+01  0.3589899810E+01  -0.3811598200E+01  1.0
# ..   ... ..               ...               ...                ...  ...
# 189  190  2  0.1239478165E+02  0.1498706237E+02   0.6529626789E+01  1.1
# 190  191  2  0.1139560639E+02  0.1360679404E+02   0.6875473407E+01  1.1
# 191  192  2  0.1057450281E+02  0.1595543238E+02   0.5103826431E+01  1.1
# 192  193  2  0.1002523743E+02  0.1566082415E+02   0.6743309885E+01  1.1
# 193  194  2  0.9568095277E+01  0.1456523324E+02   0.5452160044E+01  1.1
#
# [194 rows x 6 columns]

# %% [markdown]
# .
