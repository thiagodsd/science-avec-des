# %% [markdown]
# # 09 de outubro de 2021
#
# ## artigos
#
# A comprehensive survey and analysis of generative models in machine learning
# * ![](img/pdf.png) (mendeley) Neural Networks for Chess
# * ![](img/pdf.png) (mendeley) [[1810.09202] Graph Convolutional Reinforcement Learning](https://arxiv.org/abs/1810.09202)
# * ![](img/pdf.png) (mendeley) [Data-Driven Consumer Debt Collection via Machine Learning and Approximate Dynamic Programming](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3250755)
# * ![](img/pdf.png) (mendeley) Generative Models for City-Specific Vehicle Trajectories
# * ![](img/pdf.png) (mendeley) [A novel framework for spatio-temporal prediction of environmental data using deep learning | Scientific Reports](https://www.nature.com/articles/s41598-020-79148-7)
# * ![](img/pdf.png) (mendeley) [[2008.07119] Generative Design by Reinforcement Learning: Enhancing the Diversity of Topology Optimization Designs](https://arxiv.org/abs/2008.07119)
# * ![](img/pdf.png) (mendeley) Semi-supervised Learning with Deep Generative Models
# * ![](img/pdf.png) (mendeley) [[1511.01844] A note on the evaluation of generative models](https://arxiv.org/abs/1511.01844)
# * ![](img/pdf.png) (mendeley) Debt Collection Industry: Machine Learning
# Approach
# * ![](img/pdf.png) (mendeley) [How to say? Voice analytics of debt collection strategies - Huang - - Managerial and Decision Economics - Wiley Online Library](https://onlinelibrary.wiley.com/doi/abs/10.1002/mde.3441)
# * ![](img/pdf.png) (mendeley) Optimizing Debt Collections Using Constrained Reinforcement Learning
# * ![](img/pdf.png) (mendeley) [[2101.06286] Reinforcement learning based recommender systems: A survey](https://arxiv.org/abs/2101.06286)
#
#
# ## reinforcement
#
# - [DeepGraphMolGen, a multi-objective, computational strategy for generating molecules with desirable properties: a graph convolution and reinforcement learning approach | Journal of Cheminformatics](https://jcheminf.biomedcentral.com/articles/10.1186/s13321-020-00454-3)
# - [Deep Convolutional Q-Learning – Deep Robotics](https://vmayoral.github.io/robots,/ai,/deep/learning,/rl,/reinforcement/learning/2016/08/07/deep-convolutional-q-learning/)
# - [An Optimistic Perspective on Offline Reinforcement Learning](https://offline-rl.github.io/)
# - [Offline Reinforcement Learning Workshop](https://offline-rl-neurips.github.io/2021/)
# - [Email Marketing | Machine Learning Projects](https://dani1793.github.io/machine-learning-portfolio/email-marketing/)
#
# ## generative
#
# + [Why generative modeling?](https://jmtomczak.github.io/blog/1/1_introduction.html)
# + [Stanford University CS236: Deep Generative Models](https://deepgenerativemodels.github.io/)
# + [Generative Models by kvmanohar22](https://kvmanohar22.github.io/Generative-Models/)
# + [Generating Synthetic Sequential Data using GANs | by Armando Vieira | Towards AI](https://pub.towardsai.net/generating-synthetic-sequential-data-using-gans-a1d67a7752ac?gi=3a81fcb652d8)
# + [Temporal Convolutional Networks, The Next Revolution for Time-Series? | by Barak Or | Towards Data Science](https://towardsdatascience.com/temporal-convolutional-networks-the-next-revolution-for-time-series-8990af826567)
#
#
# ## kaggle
#
# * [Transfer Learning with VGG-16 CNN+AUG LB 0.1712 | Kaggle](https://www.kaggle.com/devm2024/transfer-learning-with-vgg-16-cnn-aug-lb-0-1712)
# * [Memorizer CGAN for dummies | Kaggle](https://www.kaggle.com/jesucristo/memorizer-cgan-for-dummies)
# * [The Convolutional Classifier | Kaggle](https://www.kaggle.com/ryanholbrook/the-convolutional-classifier)
# * [Variantional Autoencoders(VAE) | Kaggle](https://www.kaggle.com/fazilbtopal/variantional-autoencoders-vae)
# * [NLP - Topic Modeling (LDA) | Kaggle](https://www.kaggle.com/aggarwalrahul/nlp-topic-modeling-lda)
# * [Conditional Generative Adversarial Network | Kaggle](https://www.kaggle.com/arpandhatt/conditional-generative-adversarial-network)
# * [Generative Adversarial N. (GANs) for Beginners 📚 | Kaggle](https://www.kaggle.com/rafetcan/generative-adversarial-n-gans-for-beginners)
# * [Generative Adversarial Network(GAN) for Fake Image | Kaggle](https://www.kaggle.com/drvaibhavkumar/generative-adversarial-network-gan-for-fake-image)
# * [Temporal CNN | Kaggle](https://www.kaggle.com/christofhenkel/temporal-cnn)
# * [Restaurant Recommendation System Using ML 🔥 🍲 | Kaggle](https://www.kaggle.com/midouazerty/restaurant-recommendation-system-using-ml)
# * [Music Recommendation System using Spotify Dataset | Kaggle](https://www.kaggle.com/vatsalmavani/music-recommendation-system-using-spotify-dataset)
# * [Neural Network Embedding Recommendation System | Kaggle](https://www.kaggle.com/willkoehrsen/neural-network-embedding-recommendation-system)
# * [Recommender System Using Amazon Reviews | Kaggle](https://www.kaggle.com/saurav9786/recommender-system-using-amazon-reviews)

# %% [markdown]
# # 10 de outubro de 2021
#
# + [AI Expert Roadmap](https://i.am.ai/roadmap/#deep-learning-roadmap)
#
# * [Introduction to Generative Adversarial Networks | Kaggle](https://www.kaggle.com/roydatascience/introduction-to-generative-adversarial-networks)
# * [Running Your First GAN | Kaggle](https://www.kaggle.com/dansbecker/running-your-first-gan)
# * [train Swin_T[pytorch lightning] | Kaggle](https://www.kaggle.com/phalanx/train-swin-t-pytorch-lightning)
# * [GAN Anime Faces | Kaggle](https://www.kaggle.com/nassimyagoub/gan-anime-faces)
# * [Kaggle Competition – Kaggle Blog – Medium](https://medium.com/kaggle-blog/tagged/kaggle-competition)
# * [Image-Based CNN | Kaggle](https://www.kaggle.com/jpmiller/image-based-cnn)
# * [Create and Train ResNet50 from scratch | Kaggle](https://www.kaggle.com/sandy1112/create-and-train-resnet50-from-scratch)
# * [Visualizing Convolution Filters in Landmarks | Kaggle](https://www.kaggle.com/reighns/visualizing-convolution-filters-in-landmarks)
# * [QuickDraw Baseline LSTM Reading and Submission | Kaggle](https://www.kaggle.com/kmader/quickdraw-baseline-lstm-reading-and-submission)
# * [🐘Greyscale MobileNet [LB=0.892] | Kaggle](https://www.kaggle.com/gaborfodor/greyscale-mobilenet-lb-0-892)
# * [Planet: Understanding the Amazon from Space | Kaggle](https://www.kaggle.com/c/planet-understanding-the-amazon-from-space/code?competitionId=6322&sortBy=voteCount)
# * [[0.92837 on private LB] Solution with Keras | Kaggle](https://www.kaggle.com/ekami66/0-92837-on-private-lb-solution-with-keras)
# * [Planet: Understanding the Amazon deforestation from Space challenge](https://gist.github.com/EKami/33ec0172590ab9f2e3a6b757c9f9dcb4)
# * [Create a new Gist](https://gist.github.com/)
# * [EKami/planet-amazon-deforestation: The open source repository for the Kaggle Amazon forest devastation competition https://www.kaggle.com/c/planet-understanding-the-amazon-from-space](https://github.com/EKami/planet-amazon-deforestation)
# * [Multilabel Classification & Rainforest EDA | Kaggle](https://www.kaggle.com/philschmidt/multilabel-classification-rainforest-eda)
# * [Text Analysis📑Topic Modelling📚with spaCy||GENSIM | Kaggle](https://www.kaggle.com/faressayah/text-analysis-topic-modelling-with-spacy-gensim)
# * [Tutorial Notebook | Kaggle](https://www.kaggle.com/anasofiauzsoy/tutorial-notebook)
# * [✨ Gentle Introduction to GAN | Kaggle](https://www.kaggle.com/shivansh002/gentle-introduction-to-gan#Below-is-the-very-basic-architecture-of-GAN's)
# * [Neural Style Transfer: Photo to Monet | Kaggle](https://www.kaggle.com/theblackmamba31/neural-style-transfer-photo-to-monet)
# * [Introduction to CycleGAN - Monet paintings | Kaggle](https://www.kaggle.com/dimitreoliveira/introduction-to-cyclegan-monet-paintings)
# * [Getting started with GANs | Kaggle](https://www.kaggle.com/ruchi798/getting-started-with-gans)
# * [Monet CycleGAN Tutorial | Kaggle](https://www.kaggle.com/amyjang/monet-cyclegan-tutorial)
# * [Stocks 📈 Reinforcement Learning Ensemble | Kaggle](https://www.kaggle.com/alincijov/stocks-reinforcement-learning-ensemble)
# * [thiagodsd | Contributor | Kaggle](https://www.kaggle.com/thiagodsd)
# * [train Swin_T[pytorch lightning] | Kaggle](https://www.kaggle.com/phalanx/train-swin-t-pytorch-lightning)
# * [Best Values in Deep Learning Cloud Providers | Kaggle](https://www.kaggle.com/discdiver/best-values-in-deep-learning-cloud-providers)
# * [Data Science in the Cloud: Who wins the cloud war? | Kaggle](https://www.kaggle.com/nitishabharathi/data-science-in-the-cloud-who-wins-the-cloud-war)
# * [tutorial training model aws site:github.io - Pesquisa Google](https://www.google.com/search?q=tutorial+training+model+aws+site%3Agithub.io&client=ubuntu&hs=mnK&channel=fs&ei=7xRjYbWZMvLN1sQP9_yY8Ak&ved=0ahUKEwj1zOHxocDzAhXyppUCHXc-Bp4Q4dUDCA4&uact=5&oq=tutorial+training+model+aws+site%3Agithub.io&gs_lcp=Cgdnd3Mtd2l6EAM6BwgAEEcQsANKBAhBGABQvQ9Y5BNg6hRoAXACeACAAWCIAdwCkgEBNJgBAKABAcgBCMABAQ&sclient=gws-wiz)
# * [Lesson 4 - Amazon Machine Learning Modeling](https://noahgift.github.io/aws-ml-guide/lessons/Lesson4_AWSML_Modeling.html)
# * [How to train a Neural Network in the Cloud? | Janis Juppe](https://jjuppe.github.io/2018/08/27/neural-networks-cloud.html)
# * [8 Create and Run a Multi-Layer Perceptron Model Using Neural Networks | Using AWS EC2 Compute and S3 Storage for Model Fitting](https://iqss.github.io/dss-ec2gui/create-and-run-a-multi-layer-perceptron-model-using-neural-networks.html)
# * [AWS Tutorial](https://cs231n.github.io/aws-tutorial/)
# * [Build, Train and Deploy Tensorflow Deep Learning Models on Amazon SageMaker: A Complete Workflow Guide - Paul Karikari](https://paulkarikari.com/machine-learning/Build-Train-and-Deploy-Tensorflow-Deep-Learning-Models-on-Amazon-SageMaker-A-Complete-Workflow-Guide/)
# * [AWS Management Console](https://us-east-2.console.aws.amazon.com/console/home?region=us-east-2#)
# * [A Comprehensive Guide to Training a Machine Learning Model for Question Answering | nlmatics.github.io](https://blogs.nlmatics.com/2020/08/06/A-Comprehensive-Guide-to-Training-a-Machine-Learning-Model-for-Question-Answering_.html)
# * [Preço AWS - Amazon Web Services](https://aws.amazon.com/pt/pricing/?nc2=h_ql_pr_ln)
# * [Home / Twitter](https://twitter.com/home)

# %% [markdown]
# .
